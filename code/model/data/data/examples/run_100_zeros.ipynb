# %% [markdown]
# # 🎹 Riemann Organ – Démo 100 zéros
# Écoute les 100 premiers zéros non triviaux chanter en direct

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from code.simulation import simulate
from utils.normalize_zeros import load_zeros

gammas = load_zeros("../data/odlyzko_zeros_100.txt")
print(f"Chargés {len(gammas)} zéros")

R = simulate(gammas, T=200, dt=0.01)

plt.figure(figsize=(14,5))
plt.plot(R, lw=1.5, color='#8B008B')
plt.title("Riemann Organ – Paramètre d’ordre global (100 premiers zéros)", fontsize=16)
plt.xlabel("temps (steps)")
plt.ylabel("|R(t)|")
plt.grid(alpha=0.3)
plt.show()
